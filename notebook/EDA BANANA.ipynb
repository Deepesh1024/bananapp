# %%
import numpy as np 
import pandas as pd

# %%
df = pd.read_csv('data/banana_quality.csv')
df
# Out:
#           Size    Weight  Sweetness  Softness  HarvestTime  Ripeness  \
# 0    -1.924968  0.468078   3.077832 -1.472177     0.294799  2.435570
# 1    -2.409751  0.486870   0.346921 -2.495099    -0.892213  2.067549
# 2    -0.357607  1.483176   1.568452 -2.645145    -0.647267  3.090643
# 3    -0.868524  1.566201   1.889605 -1.273761    -1.006278  1.873001
# 4     0.651825  1.319199  -0.022459 -1.209709    -1.430692  1.078345
# ...        ...       ...        ...       ...          ...       ...
# 7995 -6.414403  0.723565   1.134953  2.952763     0.297928 -0.156946
# 7996  0.851143 -2.217875  -2.812175  0.489249    -1.323410 -2.316883
# 7997  1.422722 -1.907665  -2.532364  0.964976    -0.562375 -1.834765
# 7998 -2.131904 -2.742600  -1.008029  2.126946    -0.802632 -3.580266
# 7999 -2.660879 -2.044666   0.159026  1.499706    -1.581856 -1.605859
#
#        Acidity Quality
# 0     0.271290    Good
# 1     0.307325    Good
# 2     1.427322    Good
# 3     0.477862    Good
# 4     2.812442    Good
# ...        ...     ...
# 7995  2.398091     Bad
# 7996  2.113136     Bad
# 7997  0.697361     Bad
# 7998  0.423569     Bad
# 7999  1.435644     Bad
#
# [8000 rows x 8 columns]

# %%
df['Quality'] = np.where(df['Quality'] == 'Good' , 1 , 0)

# %%
df
# Out:
#           Size    Weight  Sweetness  Softness  HarvestTime  Ripeness  \
# 0    -1.924968  0.468078   3.077832 -1.472177     0.294799  2.435570
# 1    -2.409751  0.486870   0.346921 -2.495099    -0.892213  2.067549
# 2    -0.357607  1.483176   1.568452 -2.645145    -0.647267  3.090643
# 3    -0.868524  1.566201   1.889605 -1.273761    -1.006278  1.873001
# 4     0.651825  1.319199  -0.022459 -1.209709    -1.430692  1.078345
# ...        ...       ...        ...       ...          ...       ...
# 7995 -6.414403  0.723565   1.134953  2.952763     0.297928 -0.156946
# 7996  0.851143 -2.217875  -2.812175  0.489249    -1.323410 -2.316883
# 7997  1.422722 -1.907665  -2.532364  0.964976    -0.562375 -1.834765
# 7998 -2.131904 -2.742600  -1.008029  2.126946    -0.802632 -3.580266
# 7999 -2.660879 -2.044666   0.159026  1.499706    -1.581856 -1.605859
#
#        Acidity  Quality
# 0     0.271290        1
# 1     0.307325        1
# 2     1.427322        1
# 3     0.477862        1
# 4     2.812442        1
# ...        ...      ...
# 7995  2.398091        0
# 7996  2.113136        0
# 7997  0.697361        0
# 7998  0.423569        0
# 7999  1.435644        0
#
# [8000 rows x 8 columns]

# %%
df.corr()
# Out:
#                  Size    Weight  Sweetness  Softness  HarvestTime  Ripeness  \
# Size         1.000000 -0.181933  -0.258027  0.164526     0.582014  0.042587
# Weight      -0.181933  1.000000   0.422683 -0.189908    -0.079465 -0.035276
# Sweetness   -0.258027  0.422683   1.000000 -0.095338    -0.201657  0.180095
# Softness     0.164526 -0.189908  -0.095338  1.000000     0.194734 -0.253804
# HarvestTime  0.582014 -0.079465  -0.201657  0.194734     1.000000  0.107127
# Ripeness     0.042587 -0.035276   0.180095 -0.253804     0.107127  1.000000
# Acidity     -0.140673  0.443879   0.187059 -0.146014    -0.090903 -0.351531
# Quality      0.352983  0.388789   0.377220 -0.001637     0.376600  0.350503
#
#               Acidity   Quality
# Size        -0.140673  0.352983
# Weight       0.443879  0.388789
# Sweetness    0.187059  0.377220
# Softness    -0.146014 -0.001637
# HarvestTime -0.090903  0.376600
# Ripeness    -0.351531  0.350503
# Acidity      1.000000 -0.000860
# Quality     -0.000860  1.000000

# %%
df.drop(columns= ['Acidity', 'Softness'] , inplace=True)

# %%
df
# Out:
#           Size    Weight  Sweetness  HarvestTime  Ripeness  Quality
# 0    -1.924968  0.468078   3.077832     0.294799  2.435570        1
# 1    -2.409751  0.486870   0.346921    -0.892213  2.067549        1
# 2    -0.357607  1.483176   1.568452    -0.647267  3.090643        1
# 3    -0.868524  1.566201   1.889605    -1.006278  1.873001        1
# 4     0.651825  1.319199  -0.022459    -1.430692  1.078345        1
# ...        ...       ...        ...          ...       ...      ...
# 7995 -6.414403  0.723565   1.134953     0.297928 -0.156946        0
# 7996  0.851143 -2.217875  -2.812175    -1.323410 -2.316883        0
# 7997  1.422722 -1.907665  -2.532364    -0.562375 -1.834765        0
# 7998 -2.131904 -2.742600  -1.008029    -0.802632 -3.580266        0
# 7999 -2.660879 -2.044666   0.159026    -1.581856 -1.605859        0
#
# [8000 rows x 6 columns]

# %%
from sklearn.preprocessing import StandardScaler

# %%
scaler = StandardScaler()

# %%
y = df['Quality']

# %%
y = pd.DataFrame(y)

# %%
df.drop(columns = 'Quality' , inplace=True)

# %%
x = df

# %%
x = scaler.fit_transform(x)

# %%
x
# Out:
# array([[-0.55113643,  0.60972933,  1.97505067,  0.52395094,  0.78256769],
#        [-0.77810662,  0.61905159,  0.57338529, -0.07058475,  0.60849327],
#        [ 0.18268513,  1.11329814,  1.20034726,  0.05210072,  1.09241877],
#        ...,
#        [ 1.01621574, -0.56882668, -0.90443461,  0.09462033, -1.237308  ],
#        [-0.64802151, -0.98302025, -0.12205536, -0.0257164 , -2.06293293],
#        [-0.895682  , -0.63679029,  0.47694643, -0.41600452, -1.12903488]])
